# %%
import pandas as pd 
import numpy as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')

# %%
print(df.columns)
# Out:
# Index(['CVE_DOC', 'FECHA_DOC', 'NOMBRE_VENDEDOR', 'NOMBRE_CLIENTE', 'CANT',
#        'CVE_ART', 'DESCR', 'PRECIO_UNITARIO', 'COSTO_UNITARIO',
#        'COSTO_UNITARIO_CALCULADO', 'SUBTOTAL_PARTIDA', 'COSTO_TOTAL_CALCULADO',
#        'MARGEN_UNITARIO_CALCULADO', 'MARGEN_TOTAL_CALCULADO'],
#       dtype='object')

# %%
print(df["NOMBRE_VENDEDOR"].unique())
# Out:
# ['LETICIA RAMIREZ HERNANDEZ' 'DIEGO ARMANDO LEON DURAN' 'ALFREDO CANELA'
#  'AARON NUÑO CORDOVA' 'ATENCION A CLIENTES' nan]

# %%
print(df["NOMBRE_CLIENTE"].unique())
# Out:
# ['PÚBLICO EN GENERAL' 'JUAN ANTONIO RESENDIZ UGALDE'
#  'ANA BARBARA CRUZ PALACIOS' 'OMAR RODRIGUEZ GOMEZ'
#  'AIRBUS HELICOPTERS MEXICO QUERETARO' 'FIDEICOMISO F/1596'
#  'SANDIBEEL BECERRA HURTADO' 'INDUSTRIAS NIBA' 'MOLINERA DE MEXICO'
#  'SILCA CERAMICO PRODUCTOS' 'OSCAR VALDEZ GUADARRAMA' 'ELICAMEX'
#  'APEX TOOL GROUP MANUFACTURING MEXICO' 'KWANTREATS' 'ADVANEX DE MEXICO'
#  'FRANCISCO JAVIER MEDINA SANCHEZ' 'KARINA AGUILAR TORRES'
#  'JOSE LUIS CHAVEZ LUNA' 'CLAVOS NACIONALES C.N'
#  'PEDRO ANTONIO SOTO IBARRA' 'MARIA MEDINA LEON' 'JOSE LUIS VARELA CORONA'
#  'DESECHOS INDUSTRIALES CONIN' 'REDYPLAST' 'DEACERO' 'POWERTRONICS'
#  'SENSIENT FLAVORS MEXICO' 'ENRIQUE VAZQUEZ PEREZ' 'LEANFLUENCE DE MEXICO'
#  'MARCOS FRANCISCO GOMEZ PONCE' 'APLICACIONES SILIDRIEL'
#  'JORGE RUBIN SAENZ' 'MANUFACTURAS METALICAS' 'CROPLASTIC'
#  'DAVID LLAMAS IZQUIERDO' 'COMPAÑIA VINICOLA SAN PATRICIO'
#  'ROSANA RUELAS RIOS' 'INSTITUTO POLITECNICO NACIONAL'
# ...

# %%
filtro1=df[(df["NOMBRE_VENDEDOR"]=="DIEGO ARMANDO LEON DURAN")]
filtro1
# Out:
#      CVE_DOC  FECHA_DOC           NOMBRE_VENDEDOR  \
# 2     F37041 2022-01-05  DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05  DIEGO ARMANDO LEON DURAN
# 6     F37044 2022-01-05  DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05  DIEGO ARMANDO LEON DURAN
# 9     F37049 2022-01-05  DIEGO ARMANDO LEON DURAN
# ...      ...        ...                       ...
# 519   F38005 2022-04-27  DIEGO ARMANDO LEON DURAN
# 580   F38141 2022-05-12  DIEGO ARMANDO LEON DURAN
# 731   F38459 2022-06-24  DIEGO ARMANDO LEON DURAN
# 851   F38665 2022-07-26  DIEGO ARMANDO LEON DURAN
# 1296  F39592 2022-11-16  DIEGO ARMANDO LEON DURAN
#
#                            NOMBRE_CLIENTE  CANT   CVE_ART  \
# 2               ANA BARBARA CRUZ PALACIOS     7    TP0007
# 3                    OMAR RODRIGUEZ GOMEZ     1    TP0001
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1   RP00165
# 8                      FIDEICOMISO F/1596     1  TUE00207
# 9                      FIDEICOMISO F/1596     1  TUE00207
# ...

# %%
filtro2=df.iloc[[2,5], :]
filtro2
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ         PÚBLICO EN GENERAL
#
#    CANT  CVE_ART                                  DESCR  PRECIO_UNITARIO  \
# 2     7   TP0007   TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 5     2  BP00243  BAN P INOX 55MMX235MM 450W 127V T/TOR           237.07
#
#    COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 2          177.68                    177.68           3861.29
# 5           49.41                     49.41            474.14
#
#    COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  MARGEN_TOTAL_CALCULADO
# 2                1243.73                     373.94                 2617.56
# 5                  98.82                     187.66                  375.32

# %%
filtro3=df.iloc[:, 1:3]
#filtro3=df.iloc[ :, [1,4,5]]
filtro3
# Out:
#       FECHA_DOC            NOMBRE_VENDEDOR
# 0    2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1    2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2    2022-01-05   DIEGO ARMANDO LEON DURAN
# 3    2022-01-05   DIEGO ARMANDO LEON DURAN
# 4    2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...         ...                        ...
# 1421 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425 2022-12-23         AARON NUÑO CORDOVA
#
# [1426 rows x 2 columns]

# %%
df1= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col=2)

# %%
filtro4=df1.loc[["DIEGO ARMANDO LEON DURAN", "ALFREDO CANELA"], ["FECHA_DOC"]]

# %%
filtro5=df.head()
filtro5
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#    CANT   CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0     1  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 1     1  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 2     7    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 3     1    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# 4     2   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
#
# ...

# %%
filtro6=df.tail()
filtro6
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ       SEVEN DAYS ALL SPORT
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ        REVUELTA MONTECARLO
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA             CPEG SOLUTIONS
#
#       CANT       CVE_ART                                     DESCR  \
# 1421     6  CS12F1040A00      CAS INOX 1/2"ØX3" 400W 127V EXT.30CM
# 1422     6  CS12H1050A00       CAS INOX 1/2"ØX4" 500W 127V EXT30CM
# 1423     3      TUE00394  TUB INOX 5/16"ØX300MM 5300W 220V "M" ESP
# 1424     1      TUA00470  TUB INOX 1/2"ØX500MM 10KW 220V 2 1/2"NPT
# 1425    10       RB00007   FAB  BOBINA DSD1 6 COLOCAR B/NUEVA 488V
#
#       PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# ...

# %%
filtro7=df[df["COSTO_UNITARIO"]>0000]
filtro7
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
#FILTRO Y
filtro8=df[(df["COSTO_UNITARIO"]<6000)&(df["FECHA_DOC"]=="2022-03-14")]

# %%
#FILTRO 0
filtro9=df[(df["COSTO_UNITARIO"]<6000)| (df["FECHA_DOC"]=="2022-03-14")]
filtro9
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
#FILTRO NOT
filtro10=df[~(df["FECHA_DOC"]=="2022-03-14")]
filtro10
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...
